# %%
import requests
import json


# replace YOUR_API_KEY with your actual API key from Alpha Vantage
response = requests.get('https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=IBM&interval=5min&apikey=8BHW24BYD4LUWBO8')

if response.status_code == 200:
    data = json.loads(response.content)
    print(data)
else:
    print('Error fetching data from Alpha Vantage API')
# Out:
# {'Meta Data': {'1. Information': 'Intraday (5min) open, high, low, close prices and volume', '2. Symbol': 'IBM', '3. Last Refreshed': '2023-04-21 20:00:00', '4. Interval': '5min', '5. Output Size': 'Compact', '6. Time Zone': 'US/Eastern'}, 'Time Series (5min)': {'2023-04-21 20:00:00': {'1. open': '125.7500', '2. high': '125.8400', '3. low': '125.7500', '4. close': '125.8400', '5. volume': '557'}, '2023-04-21 19:15:00': {'1. open': '125.7800', '2. high': '125.7800', '3. low': '125.7800', '4. close': '125.7800', '5. volume': '181'}, '2023-04-21 18:30:00': {'1. open': '125.8500', '2. high': '125.8500', '3. low': '125.8500', '4. close': '125.8500', '5. volume': '200'}, '2023-04-21 16:45:00': {'1. open': '125.7500', '2. high': '125.7500', '3. low': '125.7500', '4. close': '125.7500', '5. volume': '150'}, '2023-04-21 16:30:00': {'1. open': '125.7500', '2. high': '125.7500', '3. low': '125.7500', '4. close': '125.7500', '5. volume': '160'}, '2023-04-21 16:15:00': {'1. open': '125.7300', '2.
# ...

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html

# replace YOUR_API_KEY with your actual API key from Alpha Vantage
response = requests.get('https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=IBM&interval=5min&apikey=8BHW24BYD4LUWBO8')

if response.status_code == 200:
    data = json.loads(response.content)
else:
    print('Error fetching data from Alpha Vantage API')

app = dash.Dash(__name__)

app.layout = html.Div(children=[
    html.H1(children='IBM Stock Market Data'),

    dcc.Graph(
        id='example-graph',
        figure={
            'data': [
                {'x': list(data['Time Series (5min)'].keys()), 'y': [float(val['4. close']) for val in data['Time Series (5min)'].values()], 'type': 'line', 'name': 'IBM'},
            ],
            'layout': {
                'title': 'IBM Stock Market Data'
            }
        }
    )
])

if __name__ == '__main__':
    app.run_server(debug=False)
# Out:
# C:\Users\Karan Jain\AppData\Local\Temp\ipykernel_18828\650346438.py:2: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc
# C:\Users\Karan Jain\AppData\Local\Temp\ipykernel_18828\650346438.py:3: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:8050
# Press CTRL+C to quit
# 127.0.0.1 - - [24/Apr/2023 00:07:48] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Apr/2023 00:07:48] "GET /_dash-layout HTTP/1.1" 200 -
# ...
